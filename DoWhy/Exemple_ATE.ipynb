# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from datetime import date
import sklearn

from random import sample

# %%
from Formatage import Import_df
from Analyse_Dowhy import CausAnal

# %% [markdown]
# ## Selection de multiples magasins aléatoirement

# %%
store = [i for i in range(1001)]

selection1 = sample (store, k=50)
selection2 = sample (store, k=50)

# %%
causal_df = Import_df(discovery = False , store = selection1) 

CausAnal(causal_df, traitement =['Promo'], outcome=['Sales'], 
         common_c=['DayOfWeek', 'Open'], effect_mo=['Customers'])
# Out:
# /var/folders/qg/rfmd3dqx61j3sd5nn0qhqymc0000gn/T/ipykernel_26003/773956354.py:1: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   causal_df = Import_df(discovery = False , store = selection1)
# /Users/ilann.mahou/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/ilann.mahou/Desktop/Causal_Inference/DoWhy/Formatage.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
causal_df = Import_df(discovery = False , store = selection2) 

CausAnal(causal_df, traitement =['Promo'], outcome=['Sales'], 
         common_c=['DayOfWeek', 'Open'], effect_mo=['Customers'])
# Out:
# /var/folders/qg/rfmd3dqx61j3sd5nn0qhqymc0000gn/T/ipykernel_26003/424698020.py:1: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   causal_df = Import_df(discovery = False , store = selection2)
# /Users/ilann.mahou/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/ilann.mahou/Desktop/Causal_Inference/DoWhy/Formatage.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Extraire l'effet par jour

# %%
causal_df = Import_df(discovery = False , store = selection1) 

causal_df = causal_df.query(f'DayOfWeek == "lundi"')

CausAnal(causal_df, traitement =['Promo'], outcome=['Sales'], 
         common_c=['Open'], effect_mo=['Customers'])
# Out:
# /var/folders/qg/rfmd3dqx61j3sd5nn0qhqymc0000gn/T/ipykernel_26003/621715123.py:1: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   causal_df = Import_df(discovery = False , store = selection1)
# /Users/ilann.mahou/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/ilann.mahou/Desktop/Causal_Inference/DoWhy/Formatage.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
causal_df = Import_df(discovery = False , store = selection1) 
causal_df = causal_df.query(f'DayOfWeek == "vendredi"')

CausAnal(causal_df, traitement =['Promo'], outcome=['Sales'], 
         common_c=['Open'], effect_mo=['Customers'])
# Out:
# /var/folders/qg/rfmd3dqx61j3sd5nn0qhqymc0000gn/T/ipykernel_26003/2149855103.py:1: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   causal_df = Import_df(discovery = False , store = selection1)
# /Users/ilann.mahou/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/ilann.mahou/Desktop/Causal_Inference/DoWhy/Formatage.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
